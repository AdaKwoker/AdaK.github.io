# %% [markdown]
# <a href="https://colab.research.google.com/github/AdaKwoker/AdaK.github.io/blob/gh-pages/polarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from textblob import TextBlob
import altair as alt

# %%
df = pd.read_csv('YInt.csv')

# %%
df.tail()
# Out:
#                       time  ...                                            message
# 41936  2020-04-10 11:59:00  ...  next were going to watch them take down our ho...
# 41937  2020-04-10 11:59:00  ...  someone something something On someone he they...
# 41938  2020-04-10 11:59:00  ...  re: Do yall think i can take my yacht out for ...
# 41939  2020-04-10 11:59:00  ...  re: guys we have no water and mittens and i ha...
# 41940  2020-04-10 11:59:00  ...   might as well go try to help at the theater.....
#
# [5 rows x 4 columns]

# %%
# from MC3 --> location 
# from MC2 --> long, lag of each sensor record
# question: how to classify all sensor record to its correponding regions?

# visulaize on tablaue -->

# %%
data = {
         'Email':added,
        'Company':c,
        'Name':n,
        'Job title':cr,
       'location':re,
}

# %%
comment = []
polarity = []

for i in df['message'][22:50]:
  comment.append(i)
  polarity.append(TextBlob(i).polarity)
  # print("{0}:{1}".format(i,TextBlob(i).polarity))

  # into dataframe and do more later

# %%
data = {
         'Message':comment,
        'Polarity':polarity,
        'Date_Time':df['time'],
        'Region':df['location']
}

# %%
sent_table = pd.DataFrame(data)

# %%
sent_table
# Out:
#                                               Message  ...            Region
# 22                 You mangled clay-brained barnacle!  ...       Cheddarford
# 23  thrilling sale, go and vibrate things up and m...  ...         Southwest
# 24    Start using getting rumble, right away! #rumble  ...       West Parton
# 25  dramatic sale, go and move things up and make ...  ...      Palace Hills
# 26  absolutely going to snatch rumble after that s...  ...            Weston
# 27  breathtaking deals. quaking chances to make yo...  ...      Palace Hills
# 28  The rumble app is great! Definitely worth down...  ...          Southton
# 29  Only Nine days left to take advanage of this v...  ...         Safe Town
# 30  breathtaking deals. shaking chances to make yo...  ...  Terrapin Springs
# 31  Grip onto the horns, right now! You'll be glad...  ...          Southton
# 32          Only Nine days left to vibrate your life!  ...         Southwest
# ...

# %%
alt.Chart(sent_table).mark_line().encode(
    x="Date_Time:T",
    y="Polarity:Q",
    color="Region:N"
)
# Out:
# alt.Chart(...)
